# %% [markdown]
# # CRYPTOCURRENCIES

# %% [markdown]
# For this project I chose three most known cryptocurrencies: Bitcoin, Ether and Litecoin. Each of them has a different price on the market with its own price movement, which makes things even more interesting.
#
# In this project I will try to find out how did certain events on the market affect each of them. But most of all I will focus on analyzing price movements for each of them individually.

# %% [markdown]
# #### Import python libraries

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt



pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# /Users/Sara/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2862: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Getting data from the web

# %% [markdown]
# To analyze data we need to get some first. All the data is acquired from https://coinmarketcap.com/. For each cryptocurrency we get its starting and ending price for every day from its beginning. Data also contains the highest and the lowest price of a day, total amount traded for each cryptocurrency on that day (volume) and a market cap (number of coins $\times$ price per coin).
#
# In ${\color{blue} {getting\_data.py}}$ we use function $\color{orange} {download\_data\_to\_csv}$ for saving our data from web into one folder - every cryptocurrency in its own CSV file.

# %%
import getting_data

# %%
data_bitcoin = pd.read_csv('crypto_data/bitcoin.csv', parse_dates=['Date'], index_col = ['Date'])
data_ether = pd.read_csv('crypto_data/ether.csv', parse_dates=['Date'], index_col = ['Date'])
data_litecoin = pd.read_csv('crypto_data/litecoin.csv', parse_dates=['Date'], index_col = ['Date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e98b5635f442> in <module>()
# ----> 1 data_bitcoin = pd.read_csv('../crypto_data/bitcoin.csv', parse_dates=['Date'], index_col = ['Date'])
#       2 data_ether = pd.read_csv('../crypto_data/ether.csv', parse_dates=['Date'], index_col = ['Date'])
#       3 data_litecoin = pd.read_csv('../crypto_data/litecoin.csv', parse_dates=['Date'], index_col = ['Date'])
#
# NameError: name 'pd' is not defined

# %%
data_bitcoin[:5]
# Out:
#                Open     High      Low    Close       Volume    Market Cap
# Date
# 2017-12-26  14036.6  16461.2  14028.9  16099.8  13454300000  235294000000
# 2017-12-25  13995.9  14593.0  13448.9  14026.6  10664700000  234590000000
# 2017-12-24  14608.2  14626.0  12747.7  13925.8  11572300000  244824000000
# 2017-12-23  13948.7  15603.2  13828.8  14699.2  13086000000  233748000000
# 2017-12-22  15898.0  15943.4  11833.0  13831.8  22198000000  266381000000

# %% [markdown]
# ## Plotting prices of cryptocurrencies

# %% [markdown]
# #### Bitcoin

# %%
data_bitcoin['High'].plot().invert_xaxis()

# %%
data_ether['High'].plot().invert_xaxis()

# %%
data_litecoin['High'].plot().invert_xaxis()
